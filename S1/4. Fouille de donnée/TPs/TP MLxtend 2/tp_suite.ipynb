# %%
import pandas as pd
import seaborn as sns
from os import chdir
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
#chdir("mettre le chemin vers votre dossier de travail")
#chargement des données "movies"
movies = pd.read_csv('movies.csv')
#chargement des données "ratings"
ratings = pd.read_csv('ratings.csv')
#vérifications
print(movies.shape)
movies.head(2)
print(ratings.shape)
ratings.head(2)
#visualisation de la répartition des notes
sns.countplot(ratings['rating'])
#sélection de colonnes pour ratings (on ignore timestamp)
ratings = ratings[['userId','movieId','rating']]
#récupération des titres de film et rangement
idx2title = {int(row['movieId']):row['title'] for _,row in movies.iterrows()}
#récupération des ids des films qui ont une note >= 4
highratings = ratings[ratings.rating>=4]
#préparation des donnees
#pour chaque utilisateur (i.e., une transaction), on veut les ids des films(les items) qu’il a noté au moins 4.0
transactions = [[idx2title[mov] for mov in highratings[highratings.userId==user].movieId] for user in highratings.userId]
#une autre facon de construire les transactions :
#lesusers = set()
#for user in highratings.userId:
# lesusers.add(user)
#
#donnees = []
#for i in lesusers:
# #print(i)
# trans = []
# for mov in highratings[highratings.userId==i].movieId:
# trans.append(idx2title[mov])
# #print(trans)
# donnees.append(trans)
#
##print(donnees)
##print(donnees[670])
# Out:
# (9125, 3)
# (100004, 4)
# Error in callback <function flush_figures at 0x0000019D6C955870> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\aghil\anaconda3\envs\Tp1\lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File c:\Users\aghil\anaconda3\envs\Tp1\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...
